# %% [markdown]
# <p style="font-family:verdana;font-size:200%;text-align:center;">Open API : APT Price Example</p>

# %% [markdown]
# - 공공데이터포털에서 제공되는 데이터를 쉽게 수집하기 위하여 오픈 API를 이용합니다.
# - 국토교통부 아파트매매 실거래가 데이터를 수집하는 예제를 실행합니다.

# %% [markdown]
# ## 작업경로 설정

# %%
# 관련 라이브러리를 호출합니다.
import os

# %%
# 현재 작업경로를 확인합니다.
os.getcwd()
# Out:
# 'C:\\Users\\kim0m\\side_project\\PythonRPA-main\\code'

# %%
# data 폴더로 작업경로를 변경합니다.
os.chdir(path = '../data')

# %%
# 작업경로에 포함된 폴더명과 파일명을 출력합니다.
os.listdir()
# Out:
# ['APT_List_Seoul_2020.xlsx',
#  'APT_Price_Seoul_2020.xlsx',
#  'Area_Code.xlsx',
#  'covid_20210415.xlsx',
#  'daum_news_20210415.xlsx',
#  'Market_Index_20210415.xlsx',
#  'Market_Index_Form.xlsx',
#  'Naver_APT_Detail.xlsx',
#  'Open_API_Key.txt',
#  'test.txt']

# %% [markdown]
# ## HTTP 요청 실행

# %%
# 관련 라이브러리를 호출합니다.
import requests

# %%
# 요청 URL의 성분을 문자열로 각각 생성합니다.
# [참고] URL이 길면 host, path 및 operation을 나눠서 생성하고, + 기호로 결합하는 방식이 좋습니다.
host = 'http://openapi.molit.go.kr:8081'
path = '/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc'
oper = '/getRTMSDataSvcAptTrade'

# %%
# Query String의 파라미터 값을 설정합니다.
# 오퍼레이션의 예제로 설정합니다. : 서울특별시 종로구, 2015년 12월 매매
areaCd = '11110'
ymonth = '201512'

# %%
# 공공데이터포털 API Key가 포함된 텍스트 파일을 읽습니다.
apiKey = open(file = 'Open_API_Key.txt', mode = 'r').read()

# %%
# Query String을 딕셔너리로 생성합니다.
query = {'LAWD_CD': areaCd, 'DEAL_YMD': ymonth, 'serviceKey': apiKey}

# %%
# HTTP 요청을 실행합니다.
res = requests.get(url = host + path + oper, params = query)

# %% [markdown]
# ## HTTP 응답 확인

# %%
# HTTP 응답 상태코드를 확인합니다.
res.status_code
# Out:
# 200

# %%
# HTTP 응답 헤더를 확인합니다.
# [참고] Content-Type이 'xml'입니다.
res.headers
# Out:
# {'Date': 'Fri, 16 Apr 2021 00:26:44 GMT', 'Content-Type': 'application/xml', 'Set-Cookie': 'ROUTEID=.HTTP1; path=/', 'Keep-Alive': 'timeout=10, max=100', 'Connection': 'Keep-Alive', 'Transfer-Encoding': 'chunked'}

# %%
# HTTP 요청 URL만 확인합니다.
res.url
# Out:
# 'http://openapi.molit.go.kr:8081/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptTrade?LAWD_CD=11110&DEAL_YMD=201512&serviceKey=8xs1pW1WQ%2BpcNaJrwQHlAL5TCkRqfuAlNyrCCHfxaLmhGE4S2SiLnovx%2FO0Dj31Yx7clSXmHu6335QQLmkWn2A%3D%3D'

# %%
# HTTP 응답 Body를 출력합니다.
# [참고] Query String이 조립되는 과정에서 퍼센트(더블) 인코딩 문제 발생합니다. 
# [참고] 퍼센트 인코딩 문제는 웹 서버로 전달되는 문자열 '%'가 '%25'로 바뀌는 현상입니다.
res.text
# Out:
# '<?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>00</resultCode><resultMsg>NORMAL SERVICE.</resultMsg></header><body><items><item><거래금액>    82,500</거래금액><건축년도>2008</건축년도><년>2015</년><법정동> 사직동</법정동><아파트>광화문풍림스페이스본(101동~105동)</아파트><월>12</월><일>10</일><전용면적>94.51</전용면적><지번>9</지번><지역코드>11110</지역코드><층>11</층><해제사유발생일> </해제사유발생일><해제여부> </해제여부></item><item><거래금액>    60,000</거래금액><건축년도>1981</건축년도><년>2015</년><법정동> 당주동</법정동><아파트>롯데미도파광화문빌딩</아파트><월>12</월><일>22</일><전용면적>149.95</전용면적><지번>145</지번><지역코드>11110</지역코드><층>8</층><해제사유발생일> </해제사유발생일><해제여부> </해제여부></item><item><거래금액>   130,000</거래금액><건축년도>2004</건축년도><년>2015</년><법정동> 내수동</법정동><아파트>킹스매너</아파트><월>12</월><일>8</일><전용면적>194.43</전용면적><지번>110-15</지번><지역코드>11110</지역코드><층>6</층><해제사유발생일> </해제사유발생일><해제여부> </해제여부></item><item><거래금액>   105,000</거래금액><건축년도>2004</건축년도><년>2015</년><법정동> 내수동</법정동><아파트>경희궁의아침2단지</아파트><월>12</월><일>14</일><전용면적>124.17</전용면적><지번>71</지번><지역코드>11110</지역코드><층>8</층><해제사유발생일> </해제사유발생일><해제여부> </해제여부></item><item><거래금액>   120,000</거래금액><건축년도>2003</건축년도><년>2015</년><법정동> 내수동</법정동><아파트>경희궁 파크팰리스</아파트><월>12</월><일>24</일><전용면적>146.33</전용면적><지번>95</지번><지역코드>11110</지역코드><층>4</층><해제사유발생일> </해제사유발생일><해제여부> </해제여부></item><item><거래금액>    17,000</거래금액><건축년도>2014</건축년도><년>2015</년><법정동> 연건동</법정동><아파트>이화에수풀</아파트><월>12</월><일>17</일><전용면적>16.98</전용면적><지번>195-10</지번><지역코드>11110</지역코드><층>8</층><해제사유발생일> </해제사유발생일><해제여부> </해제여부></item><item><거래금액>    17,000</거래금액><건축년도>2014</건축년도><년>2015</년><법정동> 연건동</법정동><아파트>이화에수풀</아파트><월>12</월><일>18</일><전용면적>16.98</전용면적><지번>195-10</지번><지역코드>11110</지역코드><층>4</층><해제사유발생일> </해제사유발생일><해제여부> </해제여부></item><item><거래금액>    57,000</거래금액><건축년도>2006</건축년도><년>2015</년><법정동> 명륜1가</법정동><아파트>렉스빌</아파트><월>12</월><일>29</일><전용면적>106.98</전용면적><지번>19</지번><지역코드>11110</지역코드><층>3</층><해제사유발생일> </해제사유발생일><해제여부> </해제여부></item><item><거래금액>    44,000</거래금액><건축년도>1995</건축년도><년>2015</년><법정동> 명륜2가</법정동><아파트>아남1</아파트><월>12</월><일>1</일><전용면적>84.8</전용면적><지번>4</지번><지역코드>11110</지역코드><층>18</층><해제사유발생일> </해제사유발생일><해제여부> </해제여부></item><item><거래금액>    52,000</거래금액><건축년도>1995</건축년도><년>2015</년><법정동> 명륜2가</법정동><아파트>아남1</아파트><월>12</월><일>10</일><전용면적>84.9</전용면적><지번>4</지번><지역코드>11110</지역코드><층>12</층><해제사유발생일> </해제사유발생일><해제여부> </해제여부></item><item><거래금액>    49,800</거래금액><건축년도>1995</건축년도><년>2015</년><법정동> 명륜2가</법정동><아파트>아남1</아파트><월>12</월><일>19</일><전용면적>84.8</전용면적><지번>4</지번><지역코드>11110</지역코드><층>1</층><해제사유발생일> </해제사유발생일><해제여부> </해제여부></item><item><거래금액>    41,000</거래금액><건축년도>1999</건축년도><년>2015</년><법정동> 명륜2가</법정동><아파트>아남3</아파트><월>12</월><일>19</일><전용면적>61.13</전용면적><지번>237</지번><지역코드>11110</지역코드><층>7</층><해제사유발생일> </해제사유발생일><해제여부> </해제여부></item><item><거래금액>    41,000</거래금액><건축년도>1999</건축년도><년>2015</년><법정동> 창신동</법정동><아파트>두산</아파트><월>12</월><일>2</일><전용면적>59.95</전용면적><지번>232</지번><지역코드>11110</지역코드><층>9</층><해제사유발생일> </해제사유발생일><해제여부> </해제여부></item><item><거래금액>    39,900</거래금액><건축년도>2003</건축년도><년>2015</년><법정동> 창신동</법정동><아파트>창신이수</아파트><월>12</월><일>3</일><전용면적>68.06</전용면적><지번>23-816</지번><지역코드>11110</지역코드><층>8</층><해제사유발생일> </해제사유발생일><해제여부> </해제여부></item><item><거래금액>    19,500</거래금액><건축년도>1966</건축년도><년>2015</년><법정동> 창신동</법정동><아파트>동대문</아파트><월>12</월><일>3</일><전용면적>28.8</전용면적><지번>328-17</지번><지역코드>11110</지역코드><층>6</층><해제사유발생일> </해제사유발생일><해제여부> </해제여부></item><item><거래금액>    20,800</거래금액><건축년도>1966</건축년도><년>2015</년><법정동> 창신동</법정동><아파트>동대문</아파트><월>12</월><일>7</일><전용면적>28.8</전용면적><지번>328-17</지번><지역코드>11110</지역코드><층>3</층><해제사유발생일> </해제사유발생일><해제여부> </해제여부></item><item><거래금액>    27,200</거래금액><건축년도>1993</건축년도><년>2015</년><법정동> 창신동</법정동><아파트>창신쌍용2</아파트><월>12</월><일>7</일><전용면적>64.66</전용면적><지번>703</지번><지역코드>11110</지역코드><층>3</층><해제사유발생일> </해제사유발생일><해제여부> </해제여부></item><item><거래금액>    39,000</거래금액><건축년도>1999</건축년도><년>2015</년><법정동> 창신동</법정동><아파트>두산</아파트><월>12</월><일>10</일><전용면적>59.95</전용면적><지번>232</지번><지역코드>11110</지역코드><층>14</층><해제사유발생일> </해제사유발생일><해제여부> </해제여부></item><item><거래금액>    39,950</거래금액><건축년도>1993</건축년도><년>2015</년><법정동> 창신동</법정동><아파트>창신쌍용2</아파트><월>12</월><일>11</일><전용면적>115.53</전용면적><지번>703</지번><지역코드>11110</지역코드><층>2</층><해제사유발 ...

# %% [markdown]
# ## 필요한 데이터 수집
#
# - Open API로 데이터를 내려받으면 XML 또는 JSON 형태의 데이터를 다루어야 합니다.
# - 두 가지 방법을 모두 소개해드리지만, JSON 형태가 다루기 훨씬 편리합니다.

# %% [markdown]
# ### XML Parsing

# %%
# 관련 라이브러리를 호출합니다.
from xml.etree import ElementTree

# %%
# str 자료형을 xml.etree.ElementTree.Element 자료형으로 변환합니다.
tree = ElementTree.fromstring(text = res.text)

# %%
# tree의 클래스를 확인합니다.
type(tree)
# Out:
# xml.etree.ElementTree.Element

# %%
# tree에서 거래 데이터를 포함하고 있는 부모 노드로 items에 할당합니다.
# [참고] tree의 클래스는 _elementtree._element_iterator입니다.
items = tree.iter(tag = 'item')

# %%
# XML에서 필요한 노드만 선택한 결과를 저장할 빈 리스트를 생성합니다.
dat1 = list()

# %%
# 필요한 노드에서 텍스트를 추출하여 딕셔너리로 생성하고 리스트 원소로 추가합니다.
for item in items:
    row = dict()
    row['거래금액'] = item.find('거래금액').text
    row['건축년도'] = item.find('건축년도').text
    dat1.append(row)

# %%
# 최종 결과의 일부만 출력합니다.
dat1[0:5]
# Out:
# [{'거래금액': '    82,500', '건축년도': '2008'},
#  {'거래금액': '    60,000', '건축년도': '1981'},
#  {'거래금액': '   130,000', '건축년도': '2004'},
#  {'거래금액': '   105,000', '건축년도': '2004'},
#  {'거래금액': '   120,000', '건축년도': '2003'}]

# %% [markdown]
# ### JSON(dict) 자료형 변환

# %%
# 관련 라이브러리를 설치합니다.
# !pip install xmltodict

# %%
# 관련 라이브러리를 호출합니다.
import xmltodict

# %%
# str 자료형을 collections.OrderedDict 자료형으로 변환합니다.
dat2 = xmltodict.parse(xml_input = res.text)

# %%
# dat2의 클래스를 확인합니다.
type(dat2)
# Out:
# collections.OrderedDict

# %%
dat2
# Out:
# OrderedDict([('response',
#               OrderedDict([('header',
#                             OrderedDict([('resultCode', '00'),
#                                          ('resultMsg', 'NORMAL SERVICE.')])),
#                            ('body',
#                             OrderedDict([('items',
#                                           OrderedDict([('item',
#                                                         [OrderedDict([('거래금액',
#                                                                        '82,500'),
#                                                                       ('건축년도',
#                                                                        '2008'),
#                                                                       ('년',
#                                                                        '2015'),
#                                                                       ('법정동',
#                                                                        '사직동'),
#                                                                       ('아파트',
#                                                                        '광화문풍림스페이스본(101동~105동)'),
#                                                                       ('월',
#                                                                        '12'),
#                                                                       ('일',
#                                                                        '10'),
#                                                                       ('전용면적',
#                                                                        '94.51'),
#                                                                       ('지번',
#                                                                        '9'),
#                                                                       ('지역코드',
#                                                                        '11110'),
#                                                                       ('층',
#                                                                        '11'),
#                                                                       ('해제사유발생일',
#                                                                        None),
#                                                                       ('해제여부',
#                                                                        None)]),
#                                                          OrderedDict([('거래금액',
#                                                                        '60,000'),
#                                                                       ('건축년도',
#                                                                        '1981'),
#                                                                       ('년',
#                                                                        '2015'),
#                                                                       ('법정동',
#                                                                        '당주동'),
#                                                                       ('아파트',
#                                                                        '롯데미도파광화문빌딩'),
#                                                                       ('월',
#                                                                        '12'),
#                                                                       ('일',
#                                                                        '22'),
#                                                                       ('전용면적',
#                                                                        '149.95'),
#                                                                       ('지번',
#                                                                        '145'),
#                                                                       ('지역코드',
#                                                                        '11110'),
#                                                                       ('층',
#                                                                        '8'),
#                                                                       ('해제사유발생일',
#                                                                        None),
#                                                                       ('해제여부',
#                                                                        None)]),
#                                                          OrderedDict([('거래금액',
#                                                                        '130,000'),
#                                                                       ('건축년도',
#                                                                        '2004'),
#                                                                       ('년',
#                                                                        '2015'),
#                                                                       ('법정동',
#                                                                        '내수동'),
#                                                                       ('아파트',
#                                                                        '킹스매너'),
#                                                                       ('월',
#                                                                        '12'),
#                                                                       ('일',
#                                                                        '8'),
#                                                                       ('전용면적',
#                                                                        '194.43'),
#                                                                       ('지번',
#                                                                        '110-15'),
#                                                                       ('지역코드',
#                                                                        '11110'),
#                                                                       ('층',
#                                                                        '6'),
#                                                                       ('해제사유발생일',
#                                                                        None),
#                                                                       ('해제여부',
#                                                                        None)]),
#                                                          OrderedDict([('거래금액',
#                                                                        '105,000'),
#                                                                       ('건축년도',
#                                                                        '2004'),
#                                                                       ('년',
#                                                                        '2015'),
#                                                                       ('법정동',
#                                                                        '내수동'),
#                                                                       ('아파트',
#                                                                        '경희궁의아침2단지'),
#                                                                       ('월',
#                                                                        '12'),
#                                                                       ('일',
#                                                                        '14'),
#                                                                       ('전용면적',
#                                                                        '124.17'),
#                                                                       ('지번',
#                                                                        '71'),
#                                                                       ('지역코드',
#                                                                        '11110'),
#                                                                       ('층',
#                                                                        '8'),
#                                                                       ('해제사유발생일',
#                                                                        None),
#                                                                       ('해제여부',
#                                                                        None)]),
#                                                          OrderedDict([('거래금액',
#                                                                        '120,000'),
#                                                                       ('건축년도',
#                                                                        '2003'),
#                                                                       ('년',
#                                                                        '2015'),
#                                                                       ('법정동',
#                                                                        '내수동'),
#                                                                       ('아파트',
#                                                                        '경희궁 파크팰리스'),
#                                                                       ('월',
#                                                                        '12'),
#                                                                       ('일',
#                                                                        '24'),
#                                                                       ('전용면적',
#                                                                        '146.33'),
#                                                                       ('지번',
#                                                                        '95'),
#                                                                       ('지역코드',
#                                                                        '11110'),
#                                                                       ('층',
#                                                                        '4'),
#                                                                       ('해제사유발생일',
#                                                                        None),
#                                                                       ('해제여부',
#                                                                        None)]),
#                                                          OrderedDict([('거래금액',
#                                                                        '17,000'),
#                                                                       ('건축년도',
#                                                                        '2014'),
#                                                                       ('년',
#                                                                        '2015'),
#                                                                       ('법정동',
#                                                                        '연건동'),
#                                                                       ('아파트',
#                                                                        '이화에수풀'),
#                                                                       ('월',
#                                                                        '12'),
#                                                                       ('일',
#                                                                        '17'),
#                                                                       ('전용면적',
#                                                                        '16.98'),
#                                                                       ('지번',
#                                                                        '195-10'),
#                                                                       ('지역코드',
#                                                                        '11110'),
#                                                                       ('층',
#                                                                        '8'),
#                                                                       ('해제사유발생일',
#                                                                        None),
#                                                                       ('해제여부',
#                                                                        None)]),
#                                                          OrderedDict([('거래금액',
#                                                                        '17,000'),
#                                                                       ('건축년도',
#                                                                        '2014'),
#                                                                       ('년',
#                                                                        '2015'),
#                                                                       ('법정동',
#                                                                        '연건동'),
#                                                                       ('아파트',
#                                                                        '이화에수풀'),
#                                                                       ('월',
#                                                                        '12'),
#                                                                       ('일',
#                                                                        '18'),
#                                                                       ('전용면적',
#                                                                        '16.98'),
#                                                                       ('지번',
#                                                                        '195-10'),
#                                                                       ('지역코드',
#                                                                        '11110'),
#                                                                       ('층',
#                                                                        '4'),
#                                                                       ('해제사유발생일',
#                                                                        None),
#                                                                       ('해제여부',
#                                                                        None)]),
#                                                          OrderedDict([('거래금액',
#                                                                        '57,000'),
#                                                                       ('건축년도',
#                                                                        '2006'),
#                                                                       ('년',
#                                                                        '2015'),
#                                                                       ('법정동',
#                                                                        '명륜1가'),
#                                                                       ('아파트',
#                                                                        '렉스빌'),
#                                                                       ('월',
#                                                                        '12'),
#                                                                       ('일',
#                                                                        '29'),
#                                                                       ('전용면적',
#                                                                        '106.98'),
#                                                                       ('지번',
#                                                                        '19'),
#                                                                       ('지역코드',
#                                                                        '11110'),
#                                                                       ('층',
#                                                                        '3'),
#                                                                       ('해제사유발생일',
#                                                                        None),
#                                                                       ('해제여부',
#                                                                        None)]),
#                                                          OrderedDict([('거래금액',
#                                                                        '44,000'),
#                                                                       ('건축년도',
#                                                                        '1995'),
#                                                                       ('년',
#                                                                        '2015'),
#                                                                       ('법정동',
#                                                                        '명륜2가'),
#                                                                       ('아파트',
#                                                                        '아남1'),
#                                                                       ('월',
#                                                                        '12'),
#                                                                       ('일',
#                                                                        '1'),
#                                                                       ('전용면적',
#                                                                        '84.8'),
#                                                                       ('지번',
#                                                                        '4'),
#                                                                       ('지역코드',
#                                                                        '11110'),
#                                                                       ('층',
#                                                                        '18'),
#                                                                       ('해제사유발생일',
#                                                                        None),
#                                                                       ('해제여부',
#                                                                        None)]),
#                                                          OrderedDict([('거래금액',
#                                                                        '52,000'),
#                                                                       ('건축년도',
#                                                                        '1995'),
#                                                                       ('년',
#                                                                        '2015'),
#                                                                       ('법정동',
#                                                                        '명륜2가'),
#                                                                       ('아파트',
#                                                                        '아남1'),
#                                                                       ('월',
#                                                                        '12'),
#                                                                       ('일',
#                                                                        '10'),
#                                                                       ('전용면적',
#                                                                        '84.9'),
#                                                                       ('지번',
#                                                                        '4'),
#                                                                       ('지역코드',
#                                                                        '11110'),
#                                                                       ('층',
#                                                                        '12'),
#                                                                       ('해제사유발생일',
#                                                                        None),
#                                                                       ('해제여부',
#                                                                        None)]),
#                                                          OrderedDict([('거래금액',
#                                                                        '49,800'),
#                                                                       ('건축년도',
#                                                                        '1995'),
#                                                                       ('년',
#                                                                        '2015'),
#                                                                       ('법정동',
#                                                                        '명륜2가'),
#                                                                       ('아파트',
#                                                                        '아남1'),
#                                                                       ('월',
#                                                                        '12'),
#                                                                       ('일',
#                                                                        '19'),
#                                                                       ('전용면적',
#                                                                        '84.8'),
#                                                                       ('지번',
#                                                                        '4'),
#                                                                       ('지역코드',
#                                                                        '11110'),
#                                                                       ('층',
#                                                                        '1'),
#                                                                       ('해제사유발생일',
#                                                                        None),
#                                                                       ('해제여부',
#                                                                        None)]),
#                                                          OrderedDict([('거래금액',
#                                                                        '41,000'),
#                                                                       ('건축년도',
#                                                                        '1999'),
#                                                                       ('년',
#                                                                        '2015'),
#                                                                       ('법정동',
#                                                                        '명륜2가'),
#                                                                       ('아파트',
#                                                                        '아남3'),
#                                                                       ('월',
#                                                                        '12'),
#                                                                       ('일',
#                                                                        '19'),
#                                                                       ('전용면적',
#                                                                        '61.13'),
#                                                                       ('지번',
#                                                                        '237'),
#                                                                       ('지역코드',
#                                                                        '11110'),
#                                                                       ('층',
#                                                                        '7'),
#                                                                       ('해제사유발생일',
#                                                                        None),
#                                                                       ('해제여부',
#                                                                        None)]),
#                                                          OrderedDict([('거래금액',
#                                                                        '41,000'),
#                                                                       ('건축년도',
#                                                                        '1999'),
#                                                                       ('년',
#                                                                        '2015'),
#                                                                       ('법정동',
#                                                                        '창신동'),
#                                                                       ('아파트',
#                                                                        '두산'),
#                                                                       ('월',
#                                                                        '12'),
#                                                                       ('일',
#                                                                        '2'),
#                                                                       ('전용면적',
#                                                                        '59.95'),
#                                                                       ('지번',
#                                                                        '232'),
#                                                                       ('지역코드',
#                                                                        '11110'),
#                                                                       ('층',
#                                                                        '9'),
#                                                                       ('해제사유발생일',
#                                                                        None),
#                                                                       ('해제여부',
#                                                                        None)]),
#                                                          OrderedDict([('거래금액',
#                                                                        '39,900'),
#                                                                       ('건축년도',
#                                                                        '2003'),
#                                                                       ('년',
#                                                                        '2015'),
#                                                                       ('법정동',
#                                                                        '창신동'),
#                                                                       ('아파트',
#                                                                        '창신이수'),
#                                                                       ('월',
#                                                                        '12'),
#                                                                       ('일',
#                                                                        '3'),
#                                                                       ('전용면적',
#                                                                        '68.06'),
#                                                                       ('지번',
#                                                                        '23-816'),
#                                                                       ('지역코드',
#                                                                        '11110'),
#                                                                       ('층',
#                                                                        '8'),
#                                                                       ('해제사유발생일',
#                                                                        None),
#                                                                       ('해제여부',
#                                                                        None)]),
#                                                          OrderedDict([('거래금액',
#                                                                        '19,500'),
#                                                                       ('건축년도',
#                                                                        '1966'),
#                                                                       ('년',
#                                                                        '2015'),
#                                                                       ('법정동',
#                                                                        '창신동'),
#                                                                       ('아파트',
#                                                                        '동대문'),
#                                                                       ('월',
#                                                                        '12'),
#                                                                       ('일',
#                                                                        '3'),
#                                                                       ('전용면적',
#                                                                        '28.8'),
#                                                                       ('지번',
#                                                                        '328-17'),
#                                                                       ('지역코드',
#                                                                        '11110'),
#                                                                       ('층',
#                                                                        '6'),
#                                                                       ('해제사유발생일',
#                                                                        None),
#                                                                       ('해제여부',
#                                                                        None)]),
#                                                          OrderedDict([('거래금액',
#                                                                        '20,800'),
#                                                                       ('건축년도',
#                                                                        '1966'),
#                                                                       ('년',
#                                                                        '2015'),
#                                                                       ('법정동',
#                                                                        '창신동'),
#                                                                       ('아파트',
#                                                                        '동대문'),
#                                                                       ('월',
#                                                                        '12'),
#                                                                       ('일',
#                                                                        '7'),
#                                                                       ('전용면적',
#                                                                        '28.8'),
#                                                                       ('지번',
#                                                                        '328-17'),
#                                                                       ('지역코드',
#                                                                        '11110'),
#                                                                       ('층',
#                                                                        '3'),
#                                                                       ('해제사유발생일',
#                                                                        None),
#                                                                       ('해제여부',
#                                                                        None)]),
#                                                          OrderedDict([('거래금액',
#                                                                        '27,200'),
#                                                                       ('건축년도',
#                                                                        '1993'),
#                                                                       ('년',
#                                                                        '2015'),
#                                                                       ('법정동',
#                                                                        '창신동'),
#                                                                       ('아파트',
#                                                                        '창신쌍용2'),
#                                                                       ('월',
#                                                                        '12'),
#                                                                       ('일',
#                                                                        '7'),
#                                                                       ('전용면적',
#                                                                        '64.66'),
#                                                                       ('지번',
#                                                                        '703'),
#                                                                       ('지역코드',
#                                                                        '11110'),
#                                                                       ('층',
#                                                                        '3'),
#                                                                       ('해제사유발생일',
#                                                                        None),
#                                                                       ('해제여부',
#                                                                        None)]),
#                                                          OrderedDict([('거래금액',
#                                                                        '39,000'),
#                                                                       ('건축년도',
#                                                                        '1999'),
#                                                                       ('년',
#                                                                        '2015'),
#                                                                       ('법정동',
#                                                                        '창신동'),
#                                                                       ('아파트',
#                                                                        '두산'),
#                                                                       ('월',
#                                                                        '12'),
#                                                                       ('일',
#                                                                        '10'),
#                                                                       ('전용면적',
#                                                                        '59.95'),
#                                                                       ('지번',
#                                                                        '232'),
#                                                                       ('지역코드',
#                                                                        '11110'),
#                                                                       ('층',
#                                                                        '14'),
#                                                                       ('해제사유발생일',
#                                                                        None),
#                                                                       ('해제여부',
#                                                                        None)]),
#                                                          OrderedDict([('거래금액',
#                                                                        '39,950'),
#                                                                       ('건축년도',
#                                                                        '1993'),
#                                                                       ('년',
#                                                                        '2015'),
#                                                                       ('법정동',
#                                                                        '창신동'),
#                                                                       ('아파트',
#                                                                        '창신쌍용2'),
#                                                                       ('월',
#                                                                        '12'),
#                                                                       ('일',
#                                                                        '11'),
#                                                                       ('전용면적',
#                                                                        '115.53'),
#                                                                       ('지번',
#                                                                        '703'),
#                                                                       ('지역코드',
#                                                                        '11110'),
#                                                                       ('층',
#                                                                        '2'),
#                                                                       ('해제사유발생일',
#                                                                        None),
#                                                                       ('해제여부',
#                                                                        None)]),
#                                                          OrderedDict([('거래금액',
#                                                                        '34,500'),
#                                                                       ('건축년도',
#                                                                        '1992'),
#                                                                       ('년',
#                                                                        '2015'),
#                                                                       ('법정동',
#                                                                        '창신동'),
#                                                                       ('아파트',
#                                                                        '창신쌍용1'),
#                                                                       ('월',
#                                                                        '12'),
#                                                                       ('일',
#                                                                        '12'),
#                                                                       ('전용면적',
#                                                                        '79.87'),
#                                                                       ('지번',
#                                                                        '702'),
#                                                                       ('지역코드',
#                                                                        '11110'),
#                                                                       ('층',
#                                                                        '5'),
#                                                                       ('해제사유발생일',
#                                                                        None),
#                                                                       ('해제여부',
#                                                                        None)]),
#                                                          OrderedDict([('거래금액',
#                                                                        '37,000'),
#                                                                       ('건축년도',
#                                                                        '1992'),
#                                                                       ('년',
#                                                                        '2015'),
#                                                                       ('법정동',
#                                                                        '창신동'),
#                                                                       ('아파트',
#                                                                        '창신쌍용1'),
#                                                                       ('월',
#                                                                        '12'),
#                                                                       ('일',
#                                                                        '14'),
#                                                                       ('전용면적',
#                                                                        '79.87'),
#                                                                       ('지번',
#                                                                        '702'),
#                                                                       ('지역코드',
#                                                                        '11110'),
#                                                                       ('층',
#                                                                        '3'),
#                                                                       ('해제사유발생일',
#                                                                        None),
#                                                                       ('해제여부',
#                                                                        None)]),
#                                                          OrderedDict([('거래금액',
#                                                                        '42,800'),
#                                                                       ('건축년도',
#                                                                        '1992'),
#                                                                       ('년',
#                                                                        '2015'),
#                                                                       ('법정동',
#                                                                        '창신동'),
#                                                                       ('아파트',
#                                                                        '창신쌍용1'),
#                                                                       ('월',
#                                                                        '12'),
#                                                                       ('일',
#                                                                        '22'),
#                                                                       ('전용면적',
#                                                                        '106.62'),
#                                                                       ('지번',
#                                                                        '702'),
#                                                                       ('지역코드',
#                                                                        '11110'),
#                                                                       ('층',
#                                                                        '12'),
#                                                                       ('해제사유발생일',
#                                                                        None),
#                                                                       ('해제여부',
#                                                                        None)]),
#                                                          OrderedDict([('거래금액',
#                                                                        '37,300'),
#                                                                       ('건축년도',
#                                                                        '1992'),
#                                                                       ('년',
#                                                                        '2015'),
#                                                                       ('법정동',
#                                                                        '창신동'),
#                                                                       ('아파트',
#                                                                        '창신쌍용1'),
#                                                                       ('월',
#                                                                        '12'),
#                                                                       ('일',
#                                                                        '23'),
#                                                                       ('전용면적',
#                                                                        '79.87'),
#                                                                       ('지번',
#                                                                        '702'),
#                                                                       ('지역코드',
#                                                                        '11110'),
#                                                                       ('층',
#                                                                        '9'),
#                                                                       ('해제사유발생일',
#                                                                        None),
#                                                                       ('해제여부',
#                                                                        None)]),
#                                                          OrderedDict([('거래금액',
#                                                                        '50,000'),
#                                                                       ('건축년도',
#                                                                        '1999'),
#                                                                       ('년',
#                                                                        '2015'),
# ...
#                                                                       ('아파트',
#                                                                        '벽산블루밍평창힐스'),
#                                                                       ('월',
#                                                                        '12'),
#                                                                       ('일',
#                                                                        '2'),
#                                                                       ('전용면적',
#                                                                        '210.53'),
#                                                                       ('지번',
#                                                                        '45'),
#                                                                       ('지역코드',
#                                                                        '11110'),
#                                                                       ('층',
#                                                                        '2'),
#                                                                       ('해제사유발생일',
#                                                                        None),
#                                                                       ('해제여부',
#                                                                        None)]),
#                                                          OrderedDict([('거래금액',
#                                                                        '164,500'),
#                                                                       ('건축년도',
#                                                                        '2009'),
#                                                                       ('년',
#                                                                        '2015'),
#                                                                       ('법정동',
#                                                                        '평창동'),
#                                                                       ('아파트',
#                                                                        '롯데캐슬 로잔'),
#                                                                       ('월',
#                                                                        '12'),
#                                                                       ('일',
#                                                                        '3'),
#                                                                       ('전용면적',
#                                                                        '219.775'),
#                                                                       ('지번',
#                                                                        '108'),
#                                                                       ('지역코드',
#                                                                        '11110'),
#                                                                       ('층',
#                                                                        '3'),
#                                                                       ('해제사유발생일',
#                                                                        None),
#                                                                       ('해제여부',
#                                                                        None)]),
#                                                          OrderedDict([('거래금액',
#                                                                        '31,500'),
#                                                                       ('건축년도',
#                                                                        '1998'),
#                                                                       ('년',
#                                                                        '2015'),
#                                                                       ('법정동',
#                                                                        '평창동'),
#                                                                       ('아파트',
#                                                                        '삼성'),
#                                                                       ('월',
#                                                                        '12'),
#                                                                       ('일',
#                                                                        '6'),
#                                                                       ('전용면적',
#                                                                        '59.97'),
#                                                                       ('지번',
#                                                                        '596'),
#                                                                       ('지역코드',
#                                                                        '11110'),
#                                                                       ('층',
#                                                                        '9'),
#                                                                       ('해제사유발생일',
#                                                                        None),
#                                                                       ('해제여부',
#                                                                        None)]),
#                                                          OrderedDict([('거래금액',
#                                                                        '39,490'),
#                                                                       ('건축년도',
#                                                                        '2000'),
#                                                                       ('년',
#                                                                        '2015'),
#                                                                       ('법정동',
#                                                                        '무악동'),
#                                                                       ('아파트',
#                                                                        '현대'),
#                                                                       ('월',
#                                                                        '12'),
#                                                                       ('일',
#                                                                        '12'),
#                                                                       ('전용면적',
#                                                                        '60'),
#                                                                       ('지번',
#                                                                        '82'),
#                                                                       ('지역코드',
#                                                                        '11110'),
#                                                                       ('층',
#                                                                        '15'),
#                                                                       ('해제사유발생일',
#                                                                        None),
#                                                                       ('해제여부',
#                                                                        None)]),
#                                                          OrderedDict([('거래금액',
#                                                                        '63,490'),
#                                                                       ('건축년도',
#                                                                        '2000'),
#                                                                       ('년',
#                                                                        '2015'),
#                                                                       ('법정동',
#                                                                        '무악동'),
#                                                                       ('아파트',
#                                                                        '현대'),
#                                                                       ('월',
#                                                                        '12'),
#                                                                       ('일',
#                                                                        '15'),
#                                                                       ('전용면적',
#                                                                        '114.9'),
#                                                                       ('지번',
#                                                                        '82'),
#                                                                       ('지역코드',
#                                                                        '11110'),
#                                                                       ('층',
#                                                                        '6'),
#                                                                       ('해제사유발생일',
#                                                                        None),
#                                                                       ('해제여부',
#                                                                        None)]),
#                                                          OrderedDict([('거래금액',
#                                                                        '62,000'),
#                                                                       ('건축년도',
#                                                                        '2008'),
#                                                                       ('년',
#                                                                        '2015'),
#                                                                       ('법정동',
#                                                                        '무악동'),
#                                                                       ('아파트',
#                                                                        '인왕산아이파크'),
#                                                                       ('월',
#                                                                        '12'),
#                                                                       ('일',
#                                                                        '16'),
#                                                                       ('전용면적',
#                                                                        '84.858'),
#                                                                       ('지번',
#                                                                        '60'),
#                                                                       ('지역코드',
#                                                                        '11110'),
#                                                                       ('층',
#                                                                        '5'),
#                                                                       ('해제사유발생일',
#                                                                        None),
#                                                                       ('해제여부',
#                                                                        None)]),
#                                                          OrderedDict([('거래금액',
#                                                                        '63,400'),
#                                                                       ('건축년도',
#                                                                        '2015'),
#                                                                       ('년',
#                                                                        '2015'),
#                                                                       ('법정동',
#                                                                        '무악동'),
#                                                                       ('아파트',
#                                                                        '인왕산2차아이파크'),
#                                                                       ('월',
#                                                                        '12'),
#                                                                       ('일',
#                                                                        '22'),
#                                                                       ('전용면적',
#                                                                        '84.0284'),
#                                                                       ('지번',
#                                                                        '88'),
#                                                                       ('지역코드',
#                                                                        '11110'),
#                                                                       ('층',
#                                                                        '10'),
#                                                                       ('해제사유발생일',
#                                                                        None),
#                                                                       ('해제여부',
#                                                                        None)]),
#                                                          OrderedDict([('거래금액',
#                                                                        '61,000'),
#                                                                       ('건축년도',
#                                                                        '2008'),
#                                                                       ('년',
#                                                                        '2015'),
#                                                                       ('법정동',
#                                                                        '무악동'),
#                                                                       ('아파트',
#                                                                        '인왕산아이파크'),
#                                                                       ('월',
#                                                                        '12'),
#                                                                       ('일',
#                                                                        '25'),
#                                                                       ('전용면적',
#                                                                        '84.858'),
#                                                                       ('지번',
#                                                                        '60'),
#                                                                       ('지역코드',
#                                                                        '11110'),
#                                                                       ('층',
#                                                                        '13'),
#                                                                       ('해제사유발생일',
#                                                                        None),
#                                                                       ('해제여부',
#                                                                        None)])])])),
#                                          ('numOfRows', '10'),
#                                          ('pageNo', '1'),
#                                          ('totalCount', '49')]))]))])

# %%
# 딕셔너리를 인덱싱하듯이 key를 연결하면 리스트로 반환됩니다.
dat2['response']['body']['items']['item']
# Out:
# [OrderedDict([('거래금액', '82,500'),
#               ('건축년도', '2008'),
#               ('년', '2015'),
#               ('법정동', '사직동'),
#               ('아파트', '광화문풍림스페이스본(101동~105동)'),
#               ('월', '12'),
#               ('일', '10'),
#               ('전용면적', '94.51'),
#               ('지번', '9'),
#               ('지역코드', '11110'),
#               ('층', '11'),
#               ('해제사유발생일', None),
#               ('해제여부', None)]),
#  OrderedDict([('거래금액', '60,000'),
#               ('건축년도', '1981'),
#               ('년', '2015'),
#               ('법정동', '당주동'),
#               ('아파트', '롯데미도파광화문빌딩'),
#               ('월', '12'),
#               ('일', '22'),
#               ('전용면적', '149.95'),
#               ('지번', '145'),
#               ('지역코드', '11110'),
#               ('층', '8'),
#               ('해제사유발생일', None),
#               ('해제여부', None)]),
#  OrderedDict([('거래금액', '130,000'),
#               ('건축년도', '2004'),
#               ('년', '2015'),
#               ('법정동', '내수동'),
#               ('아파트', '킹스매너'),
#               ('월', '12'),
#               ('일', '8'),
#               ('전용면적', '194.43'),
#               ('지번', '110-15'),
#               ('지역코드', '11110'),
#               ('층', '6'),
#               ('해제사유발생일', None),
#               ('해제여부', None)]),
#  OrderedDict([('거래금액', '105,000'),
#               ('건축년도', '2004'),
#               ('년', '2015'),
#               ('법정동', '내수동'),
#               ('아파트', '경희궁의아침2단지'),
#               ('월', '12'),
#               ('일', '14'),
#               ('전용면적', '124.17'),
#               ('지번', '71'),
#               ('지역코드', '11110'),
#               ('층', '8'),
#               ('해제사유발생일', None),
#               ('해제여부', None)]),
#  OrderedDict([('거래금액', '120,000'),
#               ('건축년도', '2003'),
#               ('년', '2015'),
#               ('법정동', '내수동'),
#               ('아파트', '경희궁 파크팰리스'),
#               ('월', '12'),
#               ('일', '24'),
#               ('전용면적', '146.33'),
#               ('지번', '95'),
#               ('지역코드', '11110'),
#               ('층', '4'),
#               ('해제사유발생일', None),
#               ('해제여부', None)]),
#  OrderedDict([('거래금액', '17,000'),
#               ('건축년도', '2014'),
#               ('년', '2015'),
#               ('법정동', '연건동'),
#               ('아파트', '이화에수풀'),
#               ('월', '12'),
#               ('일', '17'),
#               ('전용면적', '16.98'),
#               ('지번', '195-10'),
#               ('지역코드', '11110'),
#               ('층', '8'),
#               ('해제사유발생일', None),
#               ('해제여부', None)]),
#  OrderedDict([('거래금액', '17,000'),
#               ('건축년도', '2014'),
#               ('년', '2015'),
#               ('법정동', '연건동'),
#               ('아파트', '이화에수풀'),
#               ('월', '12'),
#               ('일', '18'),
#               ('전용면적', '16.98'),
#               ('지번', '195-10'),
#               ('지역코드', '11110'),
#               ('층', '4'),
#               ('해제사유발생일', None),
#               ('해제여부', None)]),
#  OrderedDict([('거래금액', '57,000'),
#               ('건축년도', '2006'),
#               ('년', '2015'),
#               ('법정동', '명륜1가'),
#               ('아파트', '렉스빌'),
#               ('월', '12'),
#               ('일', '29'),
#               ('전용면적', '106.98'),
#               ('지번', '19'),
#               ('지역코드', '11110'),
#               ('층', '3'),
#               ('해제사유발생일', None),
#               ('해제여부', None)]),
#  OrderedDict([('거래금액', '44,000'),
#               ('건축년도', '1995'),
#               ('년', '2015'),
#               ('법정동', '명륜2가'),
#               ('아파트', '아남1'),
#               ('월', '12'),
#               ('일', '1'),
#               ('전용면적', '84.8'),
#               ('지번', '4'),
#               ('지역코드', '11110'),
#               ('층', '18'),
#               ('해제사유발생일', None),
#               ('해제여부', None)]),
#  OrderedDict([('거래금액', '52,000'),
#               ('건축년도', '1995'),
#               ('년', '2015'),
#               ('법정동', '명륜2가'),
#               ('아파트', '아남1'),
#               ('월', '12'),
#               ('일', '10'),
#               ('전용면적', '84.9'),
#               ('지번', '4'),
#               ('지역코드', '11110'),
#               ('층', '12'),
#               ('해제사유발생일', None),
#               ('해제여부', None)]),
#  OrderedDict([('거래금액', '49,800'),
#               ('건축년도', '1995'),
#               ('년', '2015'),
#               ('법정동', '명륜2가'),
#               ('아파트', '아남1'),
#               ('월', '12'),
#               ('일', '19'),
#               ('전용면적', '84.8'),
#               ('지번', '4'),
#               ('지역코드', '11110'),
#               ('층', '1'),
#               ('해제사유발생일', None),
#               ('해제여부', None)]),
#  OrderedDict([('거래금액', '41,000'),
#               ('건축년도', '1999'),
#               ('년', '2015'),
#               ('법정동', '명륜2가'),
#               ('아파트', '아남3'),
#               ('월', '12'),
#               ('일', '19'),
#               ('전용면적', '61.13'),
#               ('지번', '237'),
#               ('지역코드', '11110'),
#               ('층', '7'),
#               ('해제사유발생일', None),
#               ('해제여부', None)]),
#  OrderedDict([('거래금액', '41,000'),
#               ('건축년도', '1999'),
#               ('년', '2015'),
#               ('법정동', '창신동'),
#               ('아파트', '두산'),
#               ('월', '12'),
#               ('일', '2'),
#               ('전용면적', '59.95'),
#               ('지번', '232'),
#               ('지역코드', '11110'),
#               ('층', '9'),
#               ('해제사유발생일', None),
#               ('해제여부', None)]),
#  OrderedDict([('거래금액', '39,900'),
#               ('건축년도', '2003'),
#               ('년', '2015'),
#               ('법정동', '창신동'),
#               ('아파트', '창신이수'),
#               ('월', '12'),
#               ('일', '3'),
#               ('전용면적', '68.06'),
#               ('지번', '23-816'),
#               ('지역코드', '11110'),
#               ('층', '8'),
#               ('해제사유발생일', None),
#               ('해제여부', None)]),
#  OrderedDict([('거래금액', '19,500'),
#               ('건축년도', '1966'),
#               ('년', '2015'),
#               ('법정동', '창신동'),
#               ('아파트', '동대문'),
#               ('월', '12'),
#               ('일', '3'),
#               ('전용면적', '28.8'),
#               ('지번', '328-17'),
#               ('지역코드', '11110'),
#               ('층', '6'),
#               ('해제사유발생일', None),
#               ('해제여부', None)]),
#  OrderedDict([('거래금액', '20,800'),
#               ('건축년도', '1966'),
#               ('년', '2015'),
#               ('법정동', '창신동'),
#               ('아파트', '동대문'),
#               ('월', '12'),
#               ('일', '7'),
#               ('전용면적', '28.8'),
#               ('지번', '328-17'),
#               ('지역코드', '11110'),
#               ('층', '3'),
#               ('해제사유발생일', None),
#               ('해제여부', None)]),
#  OrderedDict([('거래금액', '27,200'),
#               ('건축년도', '1993'),
#               ('년', '2015'),
#               ('법정동', '창신동'),
#               ('아파트', '창신쌍용2'),
#               ('월', '12'),
#               ('일', '7'),
#               ('전용면적', '64.66'),
#               ('지번', '703'),
#               ('지역코드', '11110'),
#               ('층', '3'),
#               ('해제사유발생일', None),
#               ('해제여부', None)]),
#  OrderedDict([('거래금액', '39,000'),
#               ('건축년도', '1999'),
#               ('년', '2015'),
#               ('법정동', '창신동'),
#               ('아파트', '두산'),
#               ('월', '12'),
#               ('일', '10'),
#               ('전용면적', '59.95'),
#               ('지번', '232'),
#               ('지역코드', '11110'),
#               ('층', '14'),
#               ('해제사유발생일', None),
#               ('해제여부', None)]),
#  OrderedDict([('거래금액', '39,950'),
#               ('건축년도', '1993'),
#               ('년', '2015'),
#               ('법정동', '창신동'),
#               ('아파트', '창신쌍용2'),
#               ('월', '12'),
#               ('일', '11'),
#               ('전용면적', '115.53'),
#               ('지번', '703'),
#               ('지역코드', '11110'),
#               ('층', '2'),
#               ('해제사유발생일', None),
#               ('해제여부', None)]),
#  OrderedDict([('거래금액', '34,500'),
#               ('건축년도', '1992'),
#               ('년', '2015'),
#               ('법정동', '창신동'),
#               ('아파트', '창신쌍용1'),
#               ('월', '12'),
#               ('일', '12'),
#               ('전용면적', '79.87'),
#               ('지번', '702'),
#               ('지역코드', '11110'),
#               ('층', '5'),
#               ('해제사유발생일', None),
#               ('해제여부', None)]),
#  OrderedDict([('거래금액', '37,000'),
#               ('건축년도', '1992'),
#               ('년', '2015'),
#               ('법정동', '창신동'),
#               ('아파트', '창신쌍용1'),
#               ('월', '12'),
#               ('일', '14'),
#               ('전용면적', '79.87'),
#               ('지번', '702'),
#               ('지역코드', '11110'),
#               ('층', '3'),
#               ('해제사유발생일', None),
#               ('해제여부', None)]),
#  OrderedDict([('거래금액', '42,800'),
#               ('건축년도', '1992'),
#               ('년', '2015'),
#               ('법정동', '창신동'),
#               ('아파트', '창신쌍용1'),
#               ('월', '12'),
#               ('일', '22'),
#               ('전용면적', '106.62'),
#               ('지번', '702'),
#               ('지역코드', '11110'),
#               ('층', '12'),
#               ('해제사유발생일', None),
#               ('해제여부', None)]),
#  OrderedDict([('거래금액', '37,300'),
#               ('건축년도', '1992'),
#               ('년', '2015'),
#               ('법정동', '창신동'),
#               ('아파트', '창신쌍용1'),
#               ('월', '12'),
#               ('일', '23'),
#               ('전용면적', '79.87'),
#               ('지번', '702'),
#               ('지역코드', '11110'),
#               ('층', '9'),
#               ('해제사유발생일', None),
#               ('해제여부', None)]),
#  OrderedDict([('거래금액', '50,000'),
#               ('건축년도', '1999'),
#               ('년', '2015'),
#               ('법정동', '창신동'),
#               ('아파트', '두산'),
#               ('월', '12'),
#               ('일', '24'),
#               ('전용면적', '84.9'),
#               ('지번', '232'),
#               ('지역코드', '11110'),
#               ('층', '4'),
#               ('해제사유발생일', None),
#               ('해제여부', None)]),
#  OrderedDict([('거래금액', '12,300'),
#               ('건축년도', '2013'),
#               ('년', '2015'),
#               ('법정동', '숭인동'),
#               ('아파트', '종로아인스빌'),
#               ('월', '12'),
#               ('일', '2'),
#               ('전용면적', '12.15'),
#               ('지번', '1392-1'),
#               ('지역코드', '11110'),
#               ('층', '10'),
#               ('해제사유발생일', None),
#               ('해제여부', None)]),
#  OrderedDict([('거래금액', '52,000'),
#               ('건축년도', '2009'),
#               ('년', '2015'),
#               ('법정동', '숭인동'),
#               ('아파트', '종로청계힐스테이트'),
#               ('월', '12'),
#               ('일', '3'),
#               ('전용면적', '84.9478'),
#               ('지번', '766'),
#               ('지역코드', '11110'),
#               ('층', '19'),
#               ('해제사유발생일', None),
#               ('해제여부', None)]),
#  OrderedDict([('거래금액', '42,500'),
#               ('건축년도', '2009'),
#               ('년', '2015'),
#               ('법정동', '숭인동'),
#               ('아파트', '종로청계힐스테이트'),
#               ('월', '12'),
#               ('일', '5'),
#               ('전용면적', '59.9426'),
#               ('지번', '766'),
#               ('지역코드', '11110'),
#               ('층', '2'),
#               ('해제사유발생일', None),
#               ('해제여부', None)]),
#  OrderedDict([('거래금액', '53,300'),
#               ('건축년도', '2008'),
#               ('년', '2015'),
#               ('법정동', '숭인동'),
#               ('아파트', '종로센트레빌'),
#               ('월', '12'),
#               ('일', '5'),
#               ('전용면적', '84.92'),
#               ('지번', '2-1'),
#               ('지역코드', '11110'),
#               ('층', '10'),
#               ('해제사유발생일', None),
#               ('해제여부', None)]),
#  OrderedDict([('거래금액', '11,500'),
#               ('건축년도', '2014'),
#               ('년', '2015'),
#               ('법정동', '숭인동'),
#               ('아파트', '숭인한양LEEPS'),
#               ('월', '12'),
#               ('일', '8'),
#               ('전용면적', '12.78'),
#               ('지번', '1421-2'),
#               ('지역코드', '11110'),
#               ('층', '10'),
#               ('해제사유발생일', None),
#               ('해제여부', None)]),
#  OrderedDict([('거래금액', '13,000'),
#               ('건축년도', '2014'),
#               ('년', '2015'),
#               ('법정동', '숭인동'),
#               ('아파트', '삼전솔하임4차'),
#               ('월', '12'),
#               ('일', '8'),
#               ('전용면적', '15.09'),
#               ('지번', '318-2'),
#               ('지역코드', '11110'),
#               ('층', '15'),
#               ('해제사유발생일', None),
#               ('해제여부', None)]),
#  OrderedDict([('거래금액', '27,000'),
#               ('건축년도', '1997'),
#               ('년', '2015'),
#               ('법정동', '숭인동'),
#               ('아파트', '동문 (비동,씨동) (494-0)'),
#               ('월', '12'),
#               ('일', '9'),
#               ('전용면적', '59.94'),
#               ('지번', '494'),
#               ('지역코드', '11110'),
#               ('층', '3'),
#               ('해제사유발생일', None),
#               ('해제여부', None)]),
#  OrderedDict([('거래금액', '44,900'),
#               ('건축년도', '2009'),
#               ('년', '2015'),
#               ('법정동', '숭인동'),
#               ('아파트', '종로청계힐스테이트'),
#               ('월', '12'),
#               ('일', '14'),
#               ('전용면적', '59.9426'),
#               ('지번', '766'),
#               ('지역코드', '11110'),
#               ('층', '12'),
#               ('해제사유발생일', None),
#               ('해제여부', None)]),
#  OrderedDict([('거래금액', '11,900'),
#               ('건축년도', '2014'),
#               ('년', '2015'),
#               ('법정동', '숭인동'),
#               ('아파트', '숭인한양LEEPS'),
#               ('월', '12'),
#               ('일', '14'),
#               ('전용면적', '12.78'),
#               ('지번', '1421-2'),
#               ('지역코드', '11110'),
#               ('층', '11'),
#               ('해제사유발생일', None),
#               ('해제여부', None)]),
#  OrderedDict([('거래금액', '10,000'),
#               ('건축년도', '2013'),
#               ('년', '2015'),
#               ('법정동', '숭인동'),
#               ('아파트', '익성씨티하임'),
#               ('월', '12'),
#               ('일', '15'),
#               ('전용면적', '14.48'),
#               ('지번', '1392'),
#               ('지역코드', '11110'),
#               ('층', '14'),
#               ('해제사유발생일', None),
#               ('해제여부', None)]),
#  OrderedDict([('거래금액', '10,500'),
#               ('건축년도', '2013'),
#               ('년', '2015'),
#               ('법정동', '숭인동'),
#               ('아파트', '익성씨티하임'),
#               ('월', '12'),
#               ('일', '15'),
#               ('전용면적', '15.76'),
#               ('지번', '1392'),
#               ('지역코드', '11110'),
#               ('층', '13'),
#               ('해제사유발생일', None),
#               ('해제여부', None)]),
#  OrderedDict([('거래금액', '42,500'),
#               ('건축년도', '2008'),
#               ('년', '2015'),
#               ('법정동', '숭인동'),
#               ('아파트', '종로센트레빌'),
#               ('월', '12'),
#               ('일', '19'),
#               ('전용면적', '59.92'),
#               ('지번', '2-1'),
#               ('지역코드', '11110'),
#               ('층', '12'),
#               ('해제사유발생일', None),
#               ('해제여부', None)]),
#  OrderedDict([('거래금액', '39,700'),
#               ('건축년도', '2008'),
#               ('년', '2015'),
#               ('법정동', '숭인동'),
#               ('아파트', '종로센트레빌'),
#               ('월', '12'),
#               ('일', '22'),
#               ('전용면적', '59.92'),
#               ('지번', '2-1'),
#               ('지역코드', '11110'),
#               ('층', '1'),
#               ('해제사유발생일', None),
#               ('해제여부', None)]),
#  OrderedDict([('거래금액', '52,300'),
#               ('건축년도', '2008'),
#               ('년', '2015'),
#               ('법정동', '숭인동'),
#               ('아파트', '종로센트레빌'),
#               ('월', '12'),
#               ('일', '26'),
#               ('전용면적', '84.92'),
#               ('지번', '2-1'),
#               ('지역코드', '11110'),
#               ('층', '12'),
#               ('해제사유발생일', None),
#               ('해제여부', None)]),
#  OrderedDict([('거래금액', '10,800'),
#               ('건축년도', '2013'),
#               ('년', '2015'),
#               ('법정동', '숭인동'),
#               ('아파트', '종로유케이201'),
#               ('월', '12'),
#               ('일', '31'),
#               ('전용면적', '12.01'),
#               ('지번', '201-11'),
#               ('지역코드', '11110'),
#               ('층', '7'),
#               ('해제사유발생일', None),
#               ('해제여부', None)]),
#  OrderedDict([('거래금액', '52,500'),
#               ('건축년도', '2009'),
#               ('년', '2015'),
#               ('법정동', '숭인동'),
#               ('아파트', '종로청계힐스테이트'),
#               ('월', '12'),
#               ('일', '31'),
#               ('전용면적', '84.9478'),
#               ('지번', '766'),
#               ('지역코드', '11110'),
#               ('층', '11'),
#               ('해제사유발생일', None),
#               ('해제여부', None)]),
#  OrderedDict([('거래금액', '44,600'),
#               ('건축년도', '1995'),
#               ('년', '2015'),
#               ('법정동', '교북동'),
#               ('아파트', '동아'),
#               ('월', '12'),
#               ('일', '7'),
#               ('전용면적', '84.28'),
#               ('지번', '101'),
#               ('지역코드', '11110'),
#               ('층', '10'),
#               ('해제사유발생일', None),
#               ('해제여부', None)]),
#  OrderedDict([('거래금액', '115,000'),
#               ('건축년도', '2004'),
#               ('년', '2015'),
#               ('법정동', '평창동'),
#               ('아파트', '벽산블루밍평창힐스'),
#               ('월', '12'),
#               ('일', '2'),
#               ('전용면적', '210.53'),
#               ('지번', '45'),
#               ('지역코드', '11110'),
#               ('층', '2'),
#               ('해제사유발생일', None),
#               ('해제여부', None)]),
#  OrderedDict([('거래금액', '164,500'),
#               ('건축년도', '2009'),
#               ('년', '2015'),
#               ('법정동', '평창동'),
#               ('아파트', '롯데캐슬 로잔'),
#               ('월', '12'),
#               ('일', '3'),
#               ('전용면적', '219.775'),
#               ('지번', '108'),
#               ('지역코드', '11110'),
#               ('층', '3'),
#               ('해제사유발생일', None),
#               ('해제여부', None)]),
#  OrderedDict([('거래금액', '31,500'),
#               ('건축년도', '1998'),
#               ('년', '2015'),
#               ('법정동', '평창동'),
#               ('아파트', '삼성'),
#               ('월', '12'),
#               ('일', '6'),
#               ('전용면적', '59.97'),
#               ('지번', '596'),
#               ('지역코드', '11110'),
#               ('층', '9'),
#               ('해제사유발생일', None),
#               ('해제여부', None)]),
#  OrderedDict([('거래금액', '39,490'),
#               ('건축년도', '2000'),
#               ('년', '2015'),
#               ('법정동', '무악동'),
#               ('아파트', '현대'),
#               ('월', '12'),
#               ('일', '12'),
#               ('전용면적', '60'),
#               ('지번', '82'),
#               ('지역코드', '11110'),
#               ('층', '15'),
#               ('해제사유발생일', None),
#               ('해제여부', None)]),
#  OrderedDict([('거래금액', '63,490'),
#               ('건축년도', '2000'),
#               ('년', '2015'),
#               ('법정동', '무악동'),
#               ('아파트', '현대'),
#               ('월', '12'),
#               ('일', '15'),
#               ('전용면적', '114.9'),
#               ('지번', '82'),
#               ('지역코드', '11110'),
#               ('층', '6'),
#               ('해제사유발생일', None),
#               ('해제여부', None)]),
#  OrderedDict([('거래금액', '62,000'),
#               ('건축년도', '2008'),
#               ('년', '2015'),
#               ('법정동', '무악동'),
#               ('아파트', '인왕산아이파크'),
#               ('월', '12'),
#               ('일', '16'),
#               ('전용면적', '84.858'),
#               ('지번', '60'),
#               ('지역코드', '11110'),
#               ('층', '5'),
#               ('해제사유발생일', None),
#               ('해제여부', None)]),
#  OrderedDict([('거래금액', '63,400'),
#               ('건축년도', '2015'),
#               ('년', '2015'),
#               ('법정동', '무악동'),
#               ('아파트', '인왕산2차아이파크'),
#               ('월', '12'),
#               ('일', '22'),
#               ('전용면적', '84.0284'),
#               ('지번', '88'),
#               ('지역코드', '11110'),
#               ('층', '10'),
#               ('해제사유발생일', None),
#               ('해제여부', None)]),
#  OrderedDict([('거래금액', '61,000'),
#               ('건축년도', '2008'),
#               ('년', '2015'),
#               ('법정동', '무악동'),
#               ('아파트', '인왕산아이파크'),
#               ('월', '12'),
#               ('일', '25'),
#               ('전용면적', '84.858'),
#               ('지번', '60'),
#               ('지역코드', '11110'),
#               ('층', '13'),
#               ('해제사유발생일', None),
#               ('해제여부', None)])]

# %% [markdown]
# ### JSON을 DataFrame으로 저장

# %%
# 관련 라이브러리를 호출합니다.
import pandas as pd

# %%
# dat1을 데이터프레임으로 변환합니다.
apt1 = pd.DataFrame(data = dat1)

# %%
# 처음 다섯 행만 출력합니다.
apt1.head()
# Out:
#          거래금액  건축년도
# 0      82,500  2008
# 1      60,000  1981
# 2     130,000  2004
# 3     105,000  2004
# 4     120,000  2003

# %%
# dat2를 데이터프레임으로 변환합니다.
apt2 = pd.DataFrame(data = dat2['response']['body']['items']['item'])

# %%
# 처음 다섯 행만 출력합니다.
apt2.head()
# Out:
#       거래금액  건축년도     년  법정동                    아파트   월   일    전용면적      지번  \
# 0   82,500  2008  2015  사직동  광화문풍림스페이스본(101동~105동)  12  10   94.51       9
# 1   60,000  1981  2015  당주동             롯데미도파광화문빌딩  12  22  149.95     145
# 2  130,000  2004  2015  내수동                   킹스매너  12   8  194.43  110-15
# 3  105,000  2004  2015  내수동              경희궁의아침2단지  12  14  124.17      71
# 4  120,000  2003  2015  내수동              경희궁 파크팰리스  12  24  146.33      95
#
#     지역코드   층 해제사유발생일  해제여부
# 0  11110  11    None  None
# 1  11110   8    None  None
# 2  11110   6    None  None
# 3  11110   8    None  None
# 4  11110   4    None  None

# %% [markdown]
# <p style="font-family:verdana;font-size:200%;text-align:center;">End of Document</p>
